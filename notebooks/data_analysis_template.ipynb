# %% [markdown]
# # Local Data Analysis Template
# Keep files local. Choose work or personal scope before loading data.

# %%
import pandas as pd
from pathlib import Path
path = Path('../data/work/inbox/example.csv')
df = pd.read_csv(path)
df.head()
